# %%
import numpy as np
from readOFFiles import *

# %% [markdown]
# ## Load data

# %%
c1droute = "./c1d/"
dns_1000route = "./nhep1d1000/"
dns_5000route = "./nhep1d5000/"
ofv1_1000route = "./ofv1_1000/"
ofv1_5000route = "./ofv1_5000/"
ofv2_1000route = "./ofv2_1000/"
ofv2_5000route = "./ofv2_5000/"
ofv3_1000route = "./ofv3_1000/"
ofv3_5000route = "./ofv3_5000/"
ofv2route = "./ofv2_1000/"
ofv3route = "./o/"
#dnsroute = "./nhep1D/dnscoarse/"
sep = "/"

# %% [markdown]
# ### compare DNS results

# %%
field = "T"
ylabelname = "T"

plt.figure(figsize = (9,9))
plt.subplot(411)

dns1000Dict = readOFField(field, dns_1000route + "0.0003" + sep)
dns5000Dict = readOFField(field, dns_5000route + "0.0003" + sep)

x_1000 = np.linspace(-0.00512,0.00512,1000)
x_5000 = np.linspace(-0.00512,0.00512,5000)

plt.plot(x_1000, dns1000Dict["data"], label = "DNS results with 1000 grids")
plt.plot(x_5000, dns5000Dict["data"], label = "DNS results with 5000 grids")

plt.title("time = {}".format("0.3ms"))
plt.xlim((-0.0015,0.0015))
plt.xlabel("Distance")
plt.ylabel(ylabelname)
plt.legend()

plt.subplot(412)
dns1000Dict = readOFField(field, dns_1000route + "0.0005" + sep)
dns5000Dict = readOFField(field, dns_5000route + "0.0005" + sep)

x_1000 = np.linspace(-0.00512,0.00512,1000)
x_5000 = np.linspace(-0.00512,0.00512,5000)

plt.plot(x_1000, dns1000Dict["data"], label = "DNS results with 1000 grids")
plt.plot(x_5000, dns5000Dict["data"], label = "DNS results with 5000 grids")

plt.title("time = {}".format("0.5ms"))
plt.xlim((-0.0015,0.0015))
plt.xlabel("Distance")
plt.ylabel(ylabelname)
plt.legend()

plt.subplot(413)
dns1000Dict = readOFField(field, dns_1000route + "0.0007" + sep)
dns5000Dict = readOFField(field, dns_5000route + "0.0007" + sep)

x_1000 = np.linspace(-0.00512,0.00512,1000)
x_5000 = np.linspace(-0.00512,0.00512,5000)

plt.plot(x_1000, dns1000Dict["data"], label = "DNS results with 1000 grids")
plt.plot(x_5000, dns5000Dict["data"], label = "DNS results with 5000 grids")

plt.title("time = {}".format("0.7ms"))
plt.xlim((-0.0015,0.0015))
plt.xlabel("Distance")
plt.ylabel(ylabelname)
plt.legend()

plt.subplot(414)
dns1000Dict = readOFField(field, dns_1000route + "0.0009" + sep)
dns5000Dict = readOFField(field, dns_5000route + "0.0009" + sep)

x_1000 = np.linspace(-0.00512,0.00512,1000)
x_5000 = np.linspace(-0.00512,0.00512,5000)

plt.plot(x_1000, dns1000Dict["data"], label = "DNS results with 1000 grids")
plt.plot(x_5000, dns5000Dict["data"], label = "DNS results with 5000 grids")

plt.title("time = {}".format("0.9ms"))
plt.xlim((-0.0015,0.0015))
plt.xlabel("Distance")
plt.ylabel(ylabelname)
plt.legend()

plt.tight_layout()
plt.savefig("Tgridsensitivity.png", dpi = 200)

# %%
field = "Z"
ylabelname = "Z"
plt.figure(figsize = (9,9))
plt.subplot(411)

dns1000Dict = readOFField(field, dns_1000route + "0.0003" + sep)
dns5000Dict = readOFField(field, dns_5000route + "0.0003" + sep)

x_1000 = np.linspace(-0.00512,0.00512,1000)
x_5000 = np.linspace(-0.00512,0.00512,5000)

plt.plot(x_1000, dns1000Dict["data"], label = "DNS results with 1000 grids")
plt.plot(x_5000, dns5000Dict["data"], label = "DNS results with 5000 grids")

plt.title("time = {}".format("0.3ms"))
plt.xlim((-0.0015,0.0015))
plt.xlabel("Distance")
plt.ylabel(ylabelname)
plt.legend()

plt.subplot(412)
dns1000Dict = readOFField(field, dns_1000route + "0.0005" + sep)
dns5000Dict = readOFField(field, dns_5000route + "0.0005" + sep)

x_1000 = np.linspace(-0.00512,0.00512,1000)
x_5000 = np.linspace(-0.00512,0.00512,5000)

plt.plot(x_1000, dns1000Dict["data"], label = "DNS results with 1000 grids")
plt.plot(x_5000, dns5000Dict["data"], label = "DNS results with 5000 grids")

plt.title("time = {}".format("0.5ms"))
plt.xlim((-0.0015,0.0015))
plt.xlabel("Distance")
plt.ylabel(ylabelname)
plt.legend()

plt.subplot(413)
dns1000Dict = readOFField(field, dns_1000route + "0.0007" + sep)
dns5000Dict = readOFField(field, dns_5000route + "0.0007" + sep)

x_1000 = np.linspace(-0.00512,0.00512,1000)
x_5000 = np.linspace(-0.00512,0.00512,5000)

plt.plot(x_1000, dns1000Dict["data"], label = "DNS results with 1000 grids")
plt.plot(x_5000, dns5000Dict["data"], label = "DNS results with 5000 grids")

plt.title("time = {}".format("0.7ms"))
plt.xlim((-0.0015,0.0015))
plt.xlabel("Distance")
plt.ylabel(ylabelname)
plt.legend()

plt.subplot(414)
dns1000Dict = readOFField(field, dns_1000route + "0.0009" + sep)
dns5000Dict = readOFField(field, dns_5000route + "0.0009" + sep)

x_1000 = np.linspace(-0.00512,0.00512,1000)
x_5000 = np.linspace(-0.00512,0.00512,5000)

plt.plot(x_1000, dns1000Dict["data"], label = "DNS results with 1000 grids")
plt.plot(x_5000, dns5000Dict["data"], label = "DNS results with 5000 grids")

plt.title("time = {}".format("0.9ms"))
plt.xlim((-0.0015,0.0015))
plt.xlabel("Distance")
plt.ylabel(ylabelname)
plt.legend()

plt.tight_layout()
plt.savefig("Zgridsensitivity.png", dpi = 200)

# %% [markdown]
# ### compare different methods

# %%
field = "Z"
figname = "Zcomp"


plt.figure(figsize = (8,10))
plt.subplot(311)
time = "0.0003"
dns5000Dict = readOFField(field, dns_5000route + time + sep)
c1dDict = readOFField(field, c1droute + time + sep)
ofv1_1000Dict = readOFField(field, ofv1_1000route + time + sep)
ofv1_5000Dict = readOFField(field, ofv1_5000route + time + sep)
ofv2_1000Dict = readOFField(field, ofv2_1000route + time + sep)
ofv2_5000Dict = readOFField(field, ofv2_5000route + time + sep)
ofv3_1000Dict = readOFField(field, ofv3_1000route + time + sep)
ofv3_5000Dict = readOFField(field, ofv3_5000route + time + sep)

x_1000 = np.linspace(-0.00512,0.00512,1000)
x_5000 = np.linspace(-0.00512,0.00512,5000)

plt.plot(x_5000, dns5000Dict["data"],   label = "DNS results with 5000 grids")
plt.plot(x_1000, c1dDict["data"], label = "chem1d")
#plt.plot(x_1000, ofv1_1000Dict["data"], label = "v1_1000grids")
plt.plot(x_1000, ofv1_5000Dict["data"], label = "v1_5000grids")
#plt.plot(x_1000, ofv2_1000Dict["data"], label = "v2_1000grids")
plt.plot(x_1000, ofv2_5000Dict["data"], label = "v2_5000grids")
#plt.plot(x_1000, ofv3_1000Dict["data"], label = "v3_1000grids")
plt.plot(x_1000, ofv3_5000Dict["data"], label = "v3_5000grids")

plt.title("time = {}".format(time))
plt.xlim((0.0005,0.0015))
plt.xlabel("Distance")
plt.ylabel(field)
plt.legend()

plt.subplot(312)
time = "0.0009"
dns5000Dict = readOFField(field, dns_5000route + time + sep)
c1dDict = readOFField(field, c1droute + time + sep)
ofv1_1000Dict = readOFField(field, ofv1_1000route + time + sep)
ofv1_5000Dict = readOFField(field, ofv1_5000route + time + sep)
ofv2_1000Dict = readOFField(field, ofv2_1000route + time + sep)
ofv2_5000Dict = readOFField(field, ofv2_5000route + time + sep)
ofv3_1000Dict = readOFField(field, ofv3_1000route + time + sep)
ofv3_5000Dict = readOFField(field, ofv3_5000route + time + sep)

x_1000 = np.linspace(-0.00512,0.00512,1000)
x_5000 = np.linspace(-0.00512,0.00512,5000)

plt.plot(x_5000, dns5000Dict["data"],   label = "DNS results with 5000 grids")
plt.plot(x_1000, c1dDict["data"], label = "chem1d")
#plt.plot(x_1000, ofv1_1000Dict["data"], label = "v1_1000grids")
plt.plot(x_1000, ofv1_5000Dict["data"], label = "v1_5000grids")
#plt.plot(x_1000, ofv2_1000Dict["data"], label = "v2_1000grids")
plt.plot(x_1000, ofv2_5000Dict["data"], label = "v2_5000grids")
#plt.plot(x_1000, ofv3_1000Dict["data"], label = "v3_1000grids")
plt.plot(x_1000, ofv3_5000Dict["data"], label = "v3_5000grids")

plt.title("time = {}".format(time))
plt.xlim((0.0005,0.0015))
plt.xlabel("Distance")
plt.ylabel(field)
plt.legend()


plt.subplot(313)
time = "0.0015"
dns5000Dict = readOFField(field, dns_5000route + time + sep)
c1dDict = readOFField(field, c1droute + time + sep)
ofv1_1000Dict = readOFField(field, ofv1_1000route + time + sep)
ofv1_5000Dict = readOFField(field, ofv1_5000route + time + sep)
ofv2_1000Dict = readOFField(field, ofv2_1000route + time + sep)
ofv2_5000Dict = readOFField(field, ofv2_5000route + time + sep)
ofv3_1000Dict = readOFField(field, ofv3_1000route + time + sep)
ofv3_5000Dict = readOFField(field, ofv3_5000route + time + sep)

x_1000 = np.linspace(-0.00512,0.00512,1000)
x_5000 = np.linspace(-0.00512,0.00512,5000)

plt.plot(x_5000, dns5000Dict["data"],   label = "DNS results with 5000 grids")
plt.plot(x_1000, c1dDict["data"], label = "chem1d")
#plt.plot(x_1000, ofv1_1000Dict["data"], label = "v1_1000grids")
plt.plot(x_1000, ofv1_5000Dict["data"], label = "v1_5000grids")
#plt.plot(x_1000, ofv2_1000Dict["data"], label = "v2_1000grids")
plt.plot(x_1000, ofv2_5000Dict["data"], label = "v2_5000grids")
#plt.plot(x_1000, ofv3_1000Dict["data"], label = "v3_1000grids")
plt.plot(x_1000, ofv3_5000Dict["data"], label = "v3_5000grids")

plt.title("time = {}".format(time))
plt.xlim((0.0005,0.0015))
plt.xlabel("Distance")
plt.ylabel(field)
plt.legend()
plt.tight_layout()

plt.savefig(figname + ".png")

# %% [markdown]
# ### Lookup error investigation

# %%
time = "0.0007"
newTime = "0.0007001"
field = "Z"
sep = "/"

ofv2_1000routeNoLook = "../../Cases/nhep1d/ofv2_5000/"
dnsroute = "../../Cases/nhep1d/nhep1d1000/"
dns5000route = "../../Cases/nhep1d/nhep1d5000/"
c1droute = "../../Cases/nhep1d/lookup07/c1d/"
ofv1_1000route = "../../Cases/nhep1d/lookup07/lookupv1_1000/"
ofv1_5000route = "../../Cases/nhep1d/lookup07/lookupv1_5000/"
ofv2_1000route = "../../Cases/nhep1d/lookup07/lookupv2_1000/"
ofv2_5000route = "../../Cases/nhep1d/lookup07/lookupv2_5000/"
ofv3_1000route = "../../Cases/nhep1d/lookup07/lookupv3_1000/"
ofv3_5000route = "../../Cases/nhep1d/lookup07/lookupv3_5000/"

plt.figure(figsize = (10,10))
plt.subplot(421)
x_1000 = np.linspace(-0.000512,0.000512,1000)
simulationDict = readOFField(field, ofv2_1000routeNoLook + time + sep)
DNSDict        = readOFField(field, dnsroute + time + sep)
c1dDict       = readOFField(field, c1droute       + newTime + sep)
ofv1_1000Dict = readOFField(field, ofv1_1000route + newTime + sep)
ofv1_5000Dict = readOFField(field, ofv1_5000route + newTime + sep)
ofv2_1000Dict = readOFField(field, ofv2_1000route + newTime + sep)
ofv2_5000Dict = readOFField(field, ofv2_5000route + newTime + sep)
ofv3_1000Dict = readOFField(field, ofv3_1000route + newTime + sep)
ofv3_5000Dict = readOFField(field, ofv3_5000route + newTime + sep)

plt.plot(x_1000, c1dDict["data"], label = "chem1d")
plt.plot(x_1000, ofv1_1000Dict["data"],label = "ofv1_1000")
plt.plot(x_1000, ofv1_5000Dict["data"],label = "ofv1_5000")
plt.plot(x_1000, ofv2_1000Dict["data"],label = "ofv2_1000")
plt.plot(x_1000, ofv2_5000Dict["data"],label = "ofv2_5000")
plt.plot(x_1000, ofv3_1000Dict["data"],label = "ofv3_1000")
plt.plot(x_1000, ofv3_5000Dict["data"],label = "ofv3_5000")
plt.plot(x_1000, DNSDict["data"], label = "DNS")
plt.plot(x_1000, simulationDict["data"], 'yo',markersize = 1, label = "FGM")
plt.xlabel("x")
plt.ylabel("Z")
plt.legend()

plt.subplot(422)
field = "PV"
x_1000 = np.linspace(-0.000512,0.000512,1000)
simulationDict = readOFField(field, ofv2_1000routeNoLook + time + sep)
DNSDict        = readOFField(field, dnsroute + time + sep)
c1dDict       = readOFField(field, c1droute       + newTime + sep)
ofv1_1000Dict = readOFField(field, ofv1_1000route + newTime + sep)
ofv1_5000Dict = readOFField(field, ofv1_5000route + newTime + sep)
ofv2_1000Dict = readOFField(field, ofv2_1000route + newTime + sep)
ofv2_5000Dict = readOFField(field, ofv2_5000route + newTime + sep)
ofv3_1000Dict = readOFField(field, ofv3_1000route + newTime + sep)
ofv3_5000Dict = readOFField(field, ofv3_5000route + newTime + sep)

plt.plot(x_1000, c1dDict["data"], label = "chem1d")
plt.plot(x_1000, ofv1_1000Dict["data"],label = "ofv1_1000")
plt.plot(x_1000, ofv1_5000Dict["data"],label = "ofv1_5000")
plt.plot(x_1000, ofv2_1000Dict["data"],label = "ofv2_1000")
plt.plot(x_1000, ofv2_5000Dict["data"],label = "ofv2_5000")
plt.plot(x_1000, ofv3_1000Dict["data"],label = "ofv3_1000")
plt.plot(x_1000, ofv3_5000Dict["data"],label = "ofv3_5000")
plt.plot(x_1000, DNSDict["data"], label = "DNS")
plt.plot(x_1000, simulationDict["data"], 'yo',markersize = 1, label = "FGM")
plt.xlabel("x")
plt.ylabel("PV")
plt.legend()

plt.subplot(423)
field = "T"
x_1000 = np.linspace(-0.000512,0.000512,1000)
simulationDict = readOFField(field, ofv2_1000routeNoLook + time + sep)
DNSDict        = readOFField(field, dns_1000route + time + sep)
c1dDict       = readOFField(field, c1droute       + newTime + sep)
ofv1_1000Dict = readOFField(field, ofv1_1000route + newTime + sep)
ofv1_5000Dict = readOFField(field, ofv1_5000route + newTime + sep)
ofv2_1000Dict = readOFField(field, ofv2_1000route + newTime + sep)
ofv2_5000Dict = readOFField(field, ofv2_5000route + newTime + sep)
ofv3_1000Dict = readOFField(field, ofv3_1000route + newTime + sep)
ofv3_5000Dict = readOFField(field, ofv3_5000route + newTime + sep)

plt.plot(x_1000, c1dDict["data"], label = "chem1d")
plt.plot(x_1000, ofv1_1000Dict["data"],label = "ofv1_1000")
plt.plot(x_1000, ofv1_5000Dict["data"],label = "ofv1_5000")
plt.plot(x_1000, ofv2_1000Dict["data"],label = "ofv2_1000")
plt.plot(x_1000, ofv2_5000Dict["data"],label = "ofv2_5000")
plt.plot(x_1000, ofv3_1000Dict["data"],label = "ofv3_1000")
plt.plot(x_1000, ofv3_5000Dict["data"],label = "ofv3_5000")
plt.plot(x_1000, DNSDict["data"], markersize = 1, label = "DNS")
plt.plot(x_1000, simulationDict["data"], 'yo',markersize = 1, label = "FGM")

plt.xlim((-0.00014,-0.00008))
plt.xlabel("x")
plt.ylabel("T")
plt.legend()

plt.subplot(425)
field = "OH"
x_1000 = np.linspace(-0.000512,0.000512,1000)
simulationDict = readOFField(field, ofv2_1000routeNoLook + time + sep)
DNSDict        = readOFField(field, dns_1000route + time + sep)
c1dDict       = readOFField(field, c1droute       + newTime + sep)
ofv1_1000Dict = readOFField(field, ofv1_1000route + newTime + sep)
ofv1_5000Dict = readOFField(field, ofv1_5000route + newTime + sep)
ofv2_1000Dict = readOFField(field, ofv2_1000route + newTime + sep)
ofv2_5000Dict = readOFField(field, ofv2_5000route + newTime + sep)
ofv3_1000Dict = readOFField(field, ofv3_1000route + newTime + sep)
ofv3_5000Dict = readOFField(field, ofv3_5000route + newTime + sep)

plt.plot(x_1000, c1dDict["data"], label = "chem1d")
plt.plot(x_1000, ofv1_1000Dict["data"],label = "ofv1_1000")
#plt.plot(x_1000, ofv1_5000Dict["data"],label = "ofv1_5000")
plt.plot(x_1000, ofv2_1000Dict["data"],label = "ofv2_1000")
#plt.plot(x_1000, ofv2_5000Dict["data"],label = "ofv2_5000")
plt.plot(x_1000, ofv3_1000Dict["data"],label = "ofv3_1000")
#plt.plot(x_1000, ofv3_5000Dict["data"],label = "ofv3_5000")
plt.plot(x_1000, DNSDict["data"], markersize = 1, label = "DNS")
plt.plot(x_1000, simulationDict["data"], 'yo',markersize = 1, label = "FGM")

plt.xlim((-0.00014,-0.00008))
plt.xlabel("x")
plt.ylabel("OH")
plt.legend()

plt.subplot(426)
field = "OH"
x_1000 = np.linspace(-0.000512,0.000512,1000)
simulationDict = readOFField(field, ofv2_1000routeNoLook + time + sep)
DNSDict        = readOFField(field, dns_1000route + time + sep)
c1dDict       = readOFField(field, c1droute       + newTime + sep)
ofv1_1000Dict = readOFField(field, ofv1_1000route + newTime + sep)
ofv1_5000Dict = readOFField(field, ofv1_5000route + newTime + sep)
ofv2_1000Dict = readOFField(field, ofv2_1000route + newTime + sep)
ofv2_5000Dict = readOFField(field, ofv2_5000route + newTime + sep)
ofv3_1000Dict = readOFField(field, ofv3_1000route + newTime + sep)
ofv3_5000Dict = readOFField(field, ofv3_5000route + newTime + sep)

plt.plot(x_1000, c1dDict["data"], label = "chem1d")
#plt.plot(x_1000, ofv1_1000Dict["data"],label = "ofv1_1000")
plt.plot(x_1000, ofv1_5000Dict["data"],label = "ofv1_5000")
#plt.plot(x_1000, ofv2_1000Dict["data"],label = "ofv2_1000")
plt.plot(x_1000, ofv2_5000Dict["data"],label = "ofv2_5000")
#plt.plot(x_1000, ofv3_1000Dict["data"],label = "ofv3_1000")
plt.plot(x_1000, ofv3_5000Dict["data"],label = "ofv3_5000")
plt.plot(x_1000, DNSDict["data"], markersize = 1, label = "DNS")
plt.plot(x_1000, simulationDict["data"], 'yo',markersize = 1, label = "FGM")

plt.xlim((-0.00014,-0.00008))
plt.xlabel("x")
plt.ylabel("OH")
plt.legend()



plt.subplot(427)
field = "C7H15O2"
x_1000 = np.linspace(-0.000512,0.000512,1000)
simulationDict = readOFField(field, ofv2_1000routeNoLook + time + sep)
DNSDict        = readOFField(field, dns_1000route + time + sep)
c1dDict       = readOFField(field, c1droute       + newTime + sep)
ofv1_1000Dict = readOFField(field, ofv1_1000route + newTime + sep)
ofv1_5000Dict = readOFField(field, ofv1_5000route + newTime + sep)
ofv2_1000Dict = readOFField(field, ofv2_1000route + newTime + sep)
ofv2_5000Dict = readOFField(field, ofv2_5000route + newTime + sep)
ofv3_1000Dict = readOFField(field, ofv3_1000route + newTime + sep)
ofv3_5000Dict = readOFField(field, ofv3_5000route + newTime + sep)

plt.plot(x_1000, c1dDict["data"], label = "chem1d")
plt.plot(x_1000, ofv1_1000Dict["data"],label = "ofv1_1000")
#plt.plot(x_1000, ofv1_5000Dict["data"],label = "ofv1_5000")
plt.plot(x_1000, ofv2_1000Dict["data"],label = "ofv2_1000")
#plt.plot(x_1000, ofv2_5000Dict["data"],label = "ofv2_5000")
plt.plot(x_1000, ofv3_1000Dict["data"],label = "ofv3_1000")
#plt.plot(x_1000, ofv3_5000Dict["data"],label = "ofv3_5000")
plt.plot(x_1000, DNSDict["data"], markersize = 1, label = "DNS")
plt.plot(x_1000, simulationDict["data"], 'yo',markersize = 1, label = "FGM")

plt.xlim((-0.00008,-0.00006))
plt.xlabel("x")
plt.ylabel("C7H15O2")
plt.legend()

plt.subplot(428)
field = "C7H15O2"
x_1000 = np.linspace(-0.000512,0.000512,1000)
simulationDict = readOFField(field, ofv2_1000routeNoLook + time + sep)
DNSDict        = readOFField(field, dns_1000route + time + sep)
c1dDict       = readOFField(field, c1droute       + newTime + sep)
ofv1_1000Dict = readOFField(field, ofv1_1000route + newTime + sep)
ofv1_5000Dict = readOFField(field, ofv1_5000route + newTime + sep)
ofv2_1000Dict = readOFField(field, ofv2_1000route + newTime + sep)
ofv2_5000Dict = readOFField(field, ofv2_5000route + newTime + sep)
ofv3_1000Dict = readOFField(field, ofv3_1000route + newTime + sep)
ofv3_5000Dict = readOFField(field, ofv3_5000route + newTime + sep)

plt.plot(x_1000, c1dDict["data"], label = "chem1d")
#plt.plot(x_1000, ofv1_1000Dict["data"],label = "ofv1_1000")
plt.plot(x_1000, ofv1_5000Dict["data"],label = "ofv1_5000")
#plt.plot(x_1000, ofv2_1000Dict["data"],label = "ofv2_1000")
plt.plot(x_1000, ofv2_5000Dict["data"],label = "ofv2_5000")
#plt.plot(x_1000, ofv3_1000Dict["data"],label = "ofv3_1000")
plt.plot(x_1000, ofv3_5000Dict["data"],label = "ofv3_5000")
plt.plot(x_1000, DNSDict["data"], markersize = 1, label = "DNS")
plt.plot(x_1000, simulationDict["data"], 'yo',markersize = 1, label = "FGM")

plt.xlim((-0.00008,-0.00006))
plt.xlabel("x")
plt.ylabel("C7H15O2")
plt.legend()

plt.tight_layout()
plt.savefig("lookupCheck.png")

# %%
from scipy.interpolate import griddata
time = "0.0007"
newTime = "0.00070001"
sep = "/"

ofv3_1000route = "../../Cases/nhep1d/lookup07new/nhep1d1000/"
ofv3_1000Dict_Z  = readOFField("Z",  ofv3_1000route + newTime + sep)
ofv3_1000Dict_PV = readOFField("PV", ofv3_1000route + newTime + sep) 
T_DNSDict   = readOFField("T", ofv3_1000route + time + sep)
OH_DNSDict  = readOFField("OH", ofv3_1000route + time + sep)
RO2_DNSDict = readOFField("C7H15O2", ofv3_1000route + time + sep)
C7H16_DNSDict = readOFField("C7H16", ofv3_1000route + time + sep)
T_FGMlookupDict = readOFField("T", ofv3_1000route + newTime + sep)
OH_FGMlookupDict = readOFField("OH", ofv3_1000route + newTime + sep)
RO2_FGMlookupDict = readOFField("C7H15O2", ofv3_1000route + newTime + sep)
C7H16_FGMlookupDict = readOFField("C7H16", ofv3_1000route + newTime + sep)

# load data (Z and PV to lookup)
Z = ofv3_1000Dict_Z["data"]
PV = ofv3_1000Dict_PV["data"]
T_DNS   = T_DNSDict["data"]
OH_DNS  = OH_DNSDict["data"]
RO2_DNS = RO2_DNSDict["data"]
C7H16_DNS = C7H16_DNSDict["data"]
T_FGMlookup   = T_FGMlookupDict["data"]
OH_FGMlookup  = OH_FGMlookupDict["data"]
RO2_FGMlookup = RO2_FGMlookupDict["data"]
C7H16_FGMlookup = C7H16_FGMlookupDict["data"]

x = np.linspace(-0.000512, 0.000512, 1000)

# load table (lookup source)
PVmin_table = readOFScalarList("PVmin_table", "../../Tabulations/pyFGMTable/tableV2/")
PVmax_table = readOFScalarList("PVmax_table", "../../Tabulations/pyFGMTable/tableV2/")
T_table     = readOFScalarList("T_table",     "../../Tabulations/pyFGMTable/tableV2/")
OH_table    = readOFScalarList("OH_table",    "../../Tabulations/pyFGMTable/tableV2/")
RO2_table   = readOFScalarList("C7H15O2_table","../../Tabulations/pyFGMTable/tableV2/")
C7H16_table = readOFScalarList("C7H16_table"  ,"../../Tabulations/pyFGMTable/tableV2/")

Zdata = np.linspace(0,1,301) * np.linspace(0,1,301)
Cdata = np.linspace(0,1,501)

PVmin = PVmin_table["data"]
PVmax = PVmax_table["data"]
T     = T_table["data"]
OH    = OH_table["data"]
RO2   = RO2_table["data"]
C7H16 = C7H16_table["data"]

PVmin = np.reshape(PVmin,(301,501)).transpose()
PVmax = np.reshape(PVmax,(301,501)).transpose()
T     = np.reshape(T    ,(301,501)).transpose()
OH    = np.reshape(OH   ,(301,501)).transpose()
RO2   = np.reshape(RO2  ,(301,501)).transpose()
C7H16 = np.reshape(C7H16,(301,501)).transpose()

ZZ,CC = np.meshgrid(Zdata,Cdata)
PVPV = CC*(PVmax-PVmin) + PVmin

T_pylookup = griddata((np.array(ZZ).reshape(-1), np.array(PVPV).reshape(-1)), np.array(T).reshape(-1), (Z, PV))
OH_pylookup = griddata((np.array(ZZ).reshape(-1), np.array(PVPV).reshape(-1)), np.array(OH).reshape(-1), (Z, PV),method = "cubic")
RO2_pylookup = griddata((np.array(ZZ).reshape(-1), np.array(PVPV).reshape(-1)), np.array(RO2).reshape(-1), (Z, PV))
C7H16_pylookup = griddata((np.array(ZZ).reshape(-1), np.array(PVPV).reshape(-1)), np.array(C7H16).reshape(-1), (Z, PV))

plt.figure(figsize = (10,12))
plt.subplot(411)
plt.plot(x, T_DNS, label = "DNS")
plt.plot(x, T_FGMlookup, label = "FGMlookup")
plt.plot(x, T_pylookup, label = "pylookup")
plt.xlim((-0.0002,0.0002))
plt.xlabel("Distance")
plt.ylabel("T")
plt.legend()

plt.subplot(412)
plt.plot(x, OH_DNS, label = "DNS")
plt.plot(x, OH_FGMlookup, label = "FGMlookup")
plt.plot(x, OH_pylookup, label = "pylookup")
plt.xlim((-0.0002,0.0002))
plt.xlabel("Distance")
plt.ylabel("OH")
plt.legend()

plt.subplot(413)
plt.plot(x, RO2_DNS, label = "DNS")
plt.plot(x, RO2_FGMlookup, label = "FGMlookup")
plt.plot(x, RO2_pylookup, label = "pylookup")
plt.xlim((-0.0002,0.0002))
plt.xlabel("Distance")
plt.ylabel("RO2")
plt.legend()

plt.subplot(414)
plt.plot(x, C7H16_DNS, label = "DNS")
plt.plot(x, C7H16_FGMlookup, label = "FGMlookup")
plt.plot(x, C7H16_pylookup, label = "pylookup")
plt.xlim((-0.0002,0.0002))
plt.xlabel("Distance")
plt.ylabel("C7H16")
plt.legend()
plt.savefig("comp.png")
# Out:
# Reading PVmin_table
# Passing dimension check for field ../../Tabulations/pyFGMTable/tableV2/PVmin_table with size of the data = 150801
# Reading PVmax_table
# Passing dimension check for field ../../Tabulations/pyFGMTable/tableV2/PVmax_table with size of the data = 150801
# Reading T_table
# Passing dimension check for field ../../Tabulations/pyFGMTable/tableV2/T_table with size of the data = 150801
# Reading OH_table
# Passing dimension check for field ../../Tabulations/pyFGMTable/tableV2/OH_table with size of the data = 150801
# Reading C7H15O2_table
# Passing dimension check for field ../../Tabulations/pyFGMTable/tableV2/C7H15O2_table with size of the data = 150801
# Reading C7H16_table
# Passing dimension check for field ../../Tabulations/pyFGMTable/tableV2/C7H16_table with size of the data = 150801

# %%
def findBetween(value, array):
    # the array should be monotonically increasing
    if (value <= array[0]):
        indexPair = (0,1)
        coeffPair = (1,0)
    elif (value >= array[-1]):
        indexPair = (len(array)-2, len(array)-1)
        coeffPair = (0,1)
    else:
        for i in range(len(array)):
            if (value > array[i]):
                indexPair = (i, i+1)

                coeffLeft = (array[i+1] - value)/(array[i+1] - array[i])
                coeffPair = (coeffLeft, 1-coeffLeft)
    return indexPair, coeffPair

def lookup(fieldList, indexPair, coeffPair):
    return fieldList[indexPair[0]]*coeffPair[0] + fieldList[indexPair[1]]*coeffPair[1]

# %%
ZTableList = np.linspace(0,1,301)*np.linspace(0,1,301)
scaledPVTableList = np.linspace(0,1,501)
PVminTableList = PVmin[0,:]
PVmaxTableList = PVmax[0,:]

ZList = np.array(Z)
PVminList = np.zeros_like(ZList)
PVmaxList = np.zeros_like(ZList)
TList = np.zeros_like(ZList)
OHList = np.zeros_like(ZList)

for i, Zele in enumerate(ZList):
    indexPair, coeffPair = findBetween(Zele, ZTableList)
    if (i == 417):
        print(indexPair)
        print(coeffPair)
    PVminList[i] = lookup(PVminTableList, indexPair, coeffPair)
    PVmaxList[i] = lookup(PVmaxTableList, indexPair, coeffPair)
scaledPVList = (PV-PVminList)/(PVmaxList-PVminList)

for i in range(len(ZList)):
    ZindexPair, ZcoeffPair  = findBetween(ZList[i], ZTableList)
    PVindexPair,PVcoeffPair = findBetween(scaledPVList[i], scaledPVTableList) 
    if (i == 417):
        print(PVindexPair)
        print(PVcoeffPair)

    TList[i] = ZcoeffPair[0]*PVcoeffPair[0]*T[PVindexPair[0]][ZindexPair[0]] + \
    ZcoeffPair[0]*PVcoeffPair[1]*T[PVindexPair[0]][ZindexPair[1]] + \
    ZcoeffPair[1]*PVcoeffPair[0]*T[PVindexPair[1]][ZindexPair[0]] + \
    ZcoeffPair[1]*PVcoeffPair[1]*T[PVindexPair[1]][ZindexPair[1]]

    OHList[i] = ZcoeffPair[0]*PVcoeffPair[0]*OH[PVindexPair[0]][ZindexPair[0]] + \
    ZcoeffPair[0]*PVcoeffPair[1]*OH[PVindexPair[0]][ZindexPair[1]] + \
    ZcoeffPair[1]*PVcoeffPair[0]*OH[PVindexPair[1]][ZindexPair[0]] + \
    ZcoeffPair[1]*PVcoeffPair[1]*OH[PVindexPair[1]][ZindexPair[1]]

# %%
index = 417
print(ZList[index])
print(scaledPVList[index])
print(TList[index])
# Out:
# 0.159683
# 0.9437663902165452
# 1745.3029673826404

# %%
plt.plot(TList, label = "FGM rewrite in python")
plt.plot(T_DNS,label = "DNS")
plt.plot(T_FGMlookup,label = "FGMlookup")

plt.xlim((360,430))
plt.legend()

# %%
lookup07newroute = "../../Cases/nhep1d/lookup07/c1dnewmethod/"
dnsroute         = "../../Cases/nhep1d/nhep1d1000/"
sep              = "/"
x = np.linspace(-0.000512,0.000512,1000)

time = "0.0007"
Z_Dict = readOFField("Z", lookup07newroute + time + sep)

PV_DNS_Dict = readOFField("PV",dnsroute + time + sep)
Z = Z_Dict["data"]
PV = PV_DNS_Dict["data"]

# load chem1d tables
PVMin_table = readOFScalarList("PVmin_table", "../../Tabulations/tables/c1dtable/")
PVMax_table = readOFScalarList("PVmax_table", "../../Tabulations/tables/c1dtable/")
T_table     = readOFScalarList("T_table"    , "../../Tabulations/tables/c1dtable/")
OH_table    = readOFScalarList("OH_table"   , "../../Tabulations/tables/c1dtable/")
RO2_table   = readOFScalarList("C7H15O2_table","../../Tabulations/tables/c1dtable/")
C7H16_table = readOFScalarList("C7H16_table", "../../Tabulations/tables/c1dtable/")

PVmin = np.array(PVMin_table["data"])
PVmax = np.array(PVMax_table["data"])
T     = np.array(T_table["data"])
OH    = np.array(OH_table["data"])
RO2   = np.array(RO2_table["data"])
C7H16 = np.array(C7H16_table["data"])

PVmin = np.reshape(PVmin,(301,501)).transpose()
PVmax = np.reshape(PVmax,(301,501)).transpose()
T     = np.reshape(T    ,(301,501)).transpose()
OH    = np.reshape(OH   ,(301,501)).transpose()
RO2   = np.reshape(RO2  ,(301,501)).transpose()
C7H16 = np.reshape(C7H16,(301,501)).transpose()

# calculate with OpenFOAM interpolation realized by Python
ZTableList = np.linspace(0,1,301)*np.linspace(0,1,301)
scaledPVTableList = np.linspace(0,1,501)
PVminTableList = PVmin[0,:]
PVmaxTableList = PVmax[0,:]

ZList = np.array(Z)
PVminList = np.zeros_like(ZList)
PVmaxList = np.zeros_like(ZList)
TList = np.zeros_like(ZList)
OHList = np.zeros_like(ZList)
RO2List = np.zeros_like(ZList)
C7H16List = np.zeros_like(ZList)

for i, Zele in enumerate(ZList):
    indexPair, coeffPair = findBetween(Zele, ZTableList)
    PVminList[i] = lookup(PVminTableList, indexPair, coeffPair)
    PVmaxList[i] = lookup(PVmaxTableList, indexPair, coeffPair)
scaledPVList = (PV-PVminList)/(PVmaxList-PVminList)

for i in range(len(ZList)):
    ZindexPair, ZcoeffPair  = findBetween(ZList[i], ZTableList)
    PVindexPair,PVcoeffPair = findBetween(scaledPVList[i], scaledPVTableList) 

    TList[i] = ZcoeffPair[0]*PVcoeffPair[0]*T[PVindexPair[0]][ZindexPair[0]] + \
    ZcoeffPair[0]*PVcoeffPair[1]*T[PVindexPair[0]][ZindexPair[1]] + \
    ZcoeffPair[1]*PVcoeffPair[0]*T[PVindexPair[1]][ZindexPair[0]] + \
    ZcoeffPair[1]*PVcoeffPair[1]*T[PVindexPair[1]][ZindexPair[1]]

    OHList[i] = ZcoeffPair[0]*PVcoeffPair[0]*OH[PVindexPair[0]][ZindexPair[0]] + \
    ZcoeffPair[0]*PVcoeffPair[1]*OH[PVindexPair[0]][ZindexPair[1]] + \
    ZcoeffPair[1]*PVcoeffPair[0]*OH[PVindexPair[1]][ZindexPair[0]] + \
    ZcoeffPair[1]*PVcoeffPair[1]*OH[PVindexPair[1]][ZindexPair[1]]

    RO2List[i] = ZcoeffPair[0]*PVcoeffPair[0]*RO2[PVindexPair[0]][ZindexPair[0]] + \
    ZcoeffPair[0]*PVcoeffPair[1]*RO2[PVindexPair[0]][ZindexPair[1]] + \
    ZcoeffPair[1]*PVcoeffPair[0]*RO2[PVindexPair[1]][ZindexPair[0]] + \
    ZcoeffPair[1]*PVcoeffPair[1]*RO2[PVindexPair[1]][ZindexPair[1]]


    C7H16List[i] = ZcoeffPair[0]*PVcoeffPair[0]*C7H16[PVindexPair[0]][ZindexPair[0]] + \
    ZcoeffPair[0]*PVcoeffPair[1]*C7H16[PVindexPair[0]][ZindexPair[1]] + \
    ZcoeffPair[1]*PVcoeffPair[0]*C7H16[PVindexPair[1]][ZindexPair[0]] + \
    ZcoeffPair[1]*PVcoeffPair[1]*C7H16[PVindexPair[1]][ZindexPair[1]]

# FGM lookup and DNS
T_FGMlookup_Dict     = readOFField("T", lookup07newroute + time + sep)
C7H16_FGMlookup_Dict = readOFField("C7H16", lookup07newroute + time + sep) 
OH_FGMlookup_Dict    = readOFField("OH", lookup07newroute + time + sep)
RO2_FGMlookup_Dict   = readOFField("C7H15O2", lookup07newroute + time + sep)

T_DNS_Dict       = readOFField("T", dnsroute + time + sep)
C7H16_DNS_Dict   = readOFField("C7H16", dnsroute + time + sep)
OH_DNS_Dict      = readOFField("OH", dnsroute + time + sep)
RO2_DNS_Dict     = readOFField("C7H15O2", dnsroute + time + sep)

T_FGMlookup = T_FGMlookup_Dict["data"]
C7H16_FGMlookup = C7H16_FGMlookup_Dict["data"]
OH_FGMlookup = OH_FGMlookup_Dict["data"]
RO2_FGMlookup = RO2_FGMlookup_Dict["data"]

T_DNS       = T_DNS_Dict["data"]
C7H16_DNS   = C7H16_DNS_Dict["data"]
OH_DNS      = OH_DNS_Dict["data"]
RO2_DNS     = RO2_DNS_Dict["data"]


plt.figure(figsize = (12,14))
plt.subplot(411)
plt.plot(x, T_FGMlookup, label = "FGM lookup")
plt.plot(x, T_DNS      , label = "DNS")
plt.plot(x, TList      , label = "rewritten FGM lookup with Python")
plt.legend()
plt.xlim((-0.0002,0))
plt.xlabel("Distance / [m]")
plt.ylabel("T/[K]")

plt.subplot(412)
plt.plot(x, OH_FGMlookup, label = "FGM lookup")
plt.plot(x, OH_DNS      , label = "DNS")
plt.plot(x, OHList      , label = "rewritten FGM lookup with Python")
plt.legend()
plt.xlim((-0.0002,0))
plt.xlabel("Distance / [m]")
plt.ylabel(r"$Y_{OH}$")

plt.subplot(413)
plt.plot(x, RO2_FGMlookup, label = "FGM lookup")
plt.plot(x, RO2_DNS      , label = "DNS")
plt.plot(x, RO2List      , label = "rewritten FGM lookup with Python")
plt.legend()
plt.xlim((-0.0002,0))
plt.xlabel("Distance / [m]")
plt.ylabel(r"$Y_{RO_{2}}$")

plt.subplot(414)
plt.plot(x, C7H16_FGMlookup, label = "FGM lookup")
plt.plot(x, C7H16_DNS      , label = "DNS")
plt.plot(x, C7H16List      , label = "rewritten FGM lookup with Python")
plt.legend()
plt.xlim((-0.0002,0))
plt.xlabel("Distance / [m]")
plt.ylabel(r"$Y_{C_{7}H_{16}}$")

plt.savefig("pic.png",dpi=250)
